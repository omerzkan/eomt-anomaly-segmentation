# %%
# !nvidia-smi
# Out:
# Mon Jun  8 01:19:41 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   43C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone --branch main https://github.com/omerzkan/eomt-anomaly-segmentation.git cloned_repo_feature_omer
# %cd cloned_repo_feature_omer
# Out:
# Cloning into 'cloned_repo_feature_omer'...
# remote: Enumerating objects: 636, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 636 (delta 23), reused 56 (delta 13), pack-reused 568 (from 1)
# Receiving objects: 100% (636/636), 41.58 MiB | 17.80 MiB/s, done.
# Resolving deltas: 100% (305/305), done.
# /content/cloned_repo_feature_omer

# %%
# !pip install -r eval/requirements.txt
# !pip install -r eomt/requirements.txt
# !pip install -r requirements.txt
# Out:
# ...
# INFO: pip is looking at multiple versions of ood-metrics to determine which version is compatible with other requirements. This could take a while.
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 156.2 MB/s eta 0:00:00
# ...

# %%
# %cd /content/cloned_repo_feature_omer
# !git pull

import os

current_dir = os.getcwd()
print("current dir is: ")
if not current_dir.endswith('cloned_repo_feature_omer'):
    # %cd /content/cloned_repo_feature_omer
    print(current_dir)
else:
  print(current_dir)
# Out:
# /content/cloned_repo_feature_omer
# Already up to date.
# current dir is:
# /content/cloned_repo_feature_omer

# %%
# !rm -rf /content/saved_logits
print("Cleared all saved logits. Ready for a clean run.")
# %cd /content/cloned_repo_feature_omer
# !python3 step8/eomt_anomaly_eval.py
# Out:
# Cleared all saved logits. Ready for a clean run.
# /content/cloned_repo_feature_omer
# Extracting anomaly validation datasets...
# Extracted to /content/data/Validation_Dataset
#
#
# ***************** EoMT-COCO-trained *****************
#
# 2026-06-08 01:28:00.028731: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-08 01:28:00.093249: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 346M/346M [00:02<00:00, 146MB/s]
# ...

# %%
# !python3 step8/eomt_temperature.py
# Out:
# ...
# Temperature scaling: eomt_cityscapes
# Temperatures: [0.5, 0.75, 1.0, 1.1, 1.5, 2.0]
# Methods: ['MSP', 'MaxEntropy', 'RbA']
# ...
#   RoadAnomaly21... done
#   RoadObsticle21... done
#   FS_LostFound_full... done
#   fs_static... done
#   RoadAnomaly... done
#
# Results saved to /content/drive/MyDrive/FAIMDL/results/step8/eomt_cityscapes_temperature.json
#
# Best temperature per method per dataset AuPRC & FPR95:
#
#   RoadAnomaly21:
#     MSP:
#       T=0.5  AuPRC=74.21%  FPR95=33.73%
#       T=0.75  AuPRC=74.29%  FPR95=33.73%
#       T=1.0  AuPRC=74.36%  FPR95=33.73%
#       T=1.1  AuPRC=74.40%  FPR95=33.73%
#       T=1.5  AuPRC=74.50%  FPR95=33.73%
#       T=2.0  AuPRC=74.55%  FPR95=33.73%
#     MaxEntropy:
#       T=0.5  AuPRC=77.43%  FPR95=33.68%
#       T=0.75  AuPRC=77.71%  FPR95=33.63%
#       T=1.0  AuPRC=77.88%  FPR95=33.60%
#       T=1.1  AuPRC=77.87%  FPR95=33.58%
#       T=1.5  AuPRC=77.90%  FPR95=33.55%
#       T=2.0  AuPRC=77.91%  FPR95=33.53%
#     RbA:
# ...
