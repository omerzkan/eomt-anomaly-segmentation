# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone --branch main https://github.com/omerzkan/eomt-anomaly-segmentation.git cloned_repo_feature_omer
# %cd cloned_repo_feature_omer
# Out:
# Cloning into 'cloned_repo_feature_omer'...
# remote: Enumerating objects: 519, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 519 (delta 124), reused 163 (delta 63), pack-reused 292 (from 1)
# Receiving objects: 100% (519/519), 26.99 MiB | 44.08 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# /content/cloned_repo_feature_omer/cloned_repo_feature_omer

# %%
# %cd /content/cloned_repo_feature_omer
# !git pull

import os

current_dir = os.getcwd()
print("current dir is: ")
if not current_dir.endswith('cloned_repo_feature_omer'):
    # %cd /content/cloned_repo_feature_omer
    print(current_dir)
else:
  print(current_dir)
# Out:
# /content/cloned_repo_feature_omer
# remote: Enumerating objects: 2, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Total 2 (delta 1), reused 2 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (2/2), 241 bytes | 241.00 KiB/s, done.
# From https://github.com/omerzkan/eomt-anomaly-segmentation
#    f2565bf..bdc28f9  main       -> origin/main
# Already up to date.
# current dir is:
# /content/cloned_repo_feature_omer

# %%
# %cd /content/cloned_repo_feature_omer
# !python3 utils/build_table.py
# Out:
# /content/cloned_repo_feature_omer
# Loaded: ERFNet
# Loaded: EoMT-COCO
# Loaded: EoMT-Cityscapes
# Loaded: EoMT-Fine-tuned
#
# ================================================================================
# TABLE — AuPRC (%)
# ================================================================================
#           Model  mIoU     Method  RA-21 AuPRC  RO-21 AuPRC  FS L&F AuPRC  FS Static AuPRC  RoadAnom AuPRC
#          ERFNet 72.50        MSP        29.09         2.71          1.75             7.47           12.42
#          ERFNet 72.50   MaxLogit        38.31         4.63          3.30             9.50           15.58
#          ERFNet 72.50 MaxEntropy        30.96         3.04          2.58             8.84           12.67
#       EoMT-COCO 55.17        MSP        34.44         1.40          1.45             6.19           20.75
#       EoMT-COCO 55.17   MaxLogit        35.20         1.41          1.44             6.24           21.00
#       EoMT-COCO 55.17 MaxEntropy        41.07         3.67          1.16             5.89           23.40
#       EoMT-COCO 55.17        RbA        23.84        39.36          0.19             1.51           17.85
# EoMT-Cityscapes 81.68        MSP        74.36        90.11         25.42            54.35           75.69
# EoMT-Cityscapes 81.68   MaxLogit        73.99        90.05         25.44            54.44           75.15
# EoMT-Cityscapes 81.68 MaxEntropy        77.88        90.01         29.56            52.51           78.14
# EoMT-Cityscapes 81.68        RbA        69.99        86.97         25.97            56.11           74.62
# EoMT-Fine-tuned 78.85        MSP        57.15        73.61         27.11            53.41           54.99
# EoMT-Fine-tuned 78.85   MaxLogit        53.69        73.14         27.39            53.61           55.14
# EoMT-Fine-tuned 78.85 MaxEntropy        54.49        72.62         28.56            54.27           56.22
# EoMT-Fine-tuned 78.85        RbA        51.82        64.22         30.61            56.29           56.14
#
# ================================================================================
# TABLE — FPR95 (%)
# ================================================================================
#           Model  mIoU     Method  RA-21 FPR95  RO-21 FPR95  FS L&F FPR95  FS Static FPR95  RoadAnom FPR95
#          ERFNet 72.50        MSP        62.57        65.28         50.61            41.84           82.59
#          ERFNet 72.50   MaxLogit        59.36        48.49         45.49            40.32           73.27
#          ERFNet 72.50 MaxEntropy        62.68        65.96         50.18            41.55           82.76
#       EoMT-COCO 55.17        MSP        87.96        99.99         96.68            96.52           94.01
#       EoMT-COCO 55.17   MaxLogit        87.77        99.99         96.69            96.61           94.08
#       EoMT-COCO 55.17 MaxEntropy        80.14        99.99         96.45            97.24           92.71
#       EoMT-COCO 55.17        RbA        64.89        99.99         97.13            99.95           79.63
# EoMT-Cityscapes 81.68        MSP        33.73         0.55         14.90            34.94           19.31
# EoMT-Cityscapes 81.68   MaxLogit        33.90         0.58         14.66            34.62           19.06
# EoMT-Cityscapes 81.68 MaxEntropy        33.60         0.68         14.72            34.84           18.79
# EoMT-Cityscapes 81.68        RbA        80.06        99.95          8.79            82.68           20.41
# EoMT-Fine-tuned 78.85        MSP        98.61        25.09         26.16            39.74           16.22
# EoMT-Fine-tuned 78.85   MaxLogit        98.74        43.77         25.84            37.82           15.68
# EoMT-Fine-tuned 78.85 MaxEntropy        98.82        57.49         26.33            39.25           14.78
# EoMT-Fine-tuned 78.85        RbA        99.85        99.98         26.92            90.34           13.38
#
# Saved to /content/drive/MyDrive/FAIMDL/results/final/result_table.csv

# %%
# !python3 utils/build_temperature_table.py
# Out:
# Loaded: EoMT-Cityscapes
# Loaded: EoMT-Fine-tuned
#
#
# ====================================================================================================
# MODEL: EoMT-Cityscapes
# ====================================================================================================
#
# AuPRC (%) — Impact of Temperature Scaling
#
#     Method                                         RA-21                                         RO-21                                        FS L&F                                     FS Static                                      RoadAnom
#        MSP 74.21 | 74.29 | 74.36 | 74.40 | 74.50 | 74.55 90.10 | 90.11 | 90.11 | 90.11 | 90.11 | 90.11 25.40 | 25.41 | 25.42 | 25.42 | 25.43 | 25.44 54.33 | 54.34 | 54.35 | 54.35 | 54.35 | 54.36 75.51 | 75.62 | 75.69 | 75.71 | 75.80 | 75.87
# MaxEntropy 77.43 | 77.71 | 77.88 | 77.87 | 77.90 | 77.91 90.09 | 90.04 | 90.01 | 90.01 | 89.96 | 89.97 29.55 | 29.55 | 29.56 | 29.48 | 29.28 | 29.01 53.21 | 52.86 | 52.51 | 52.40 | 51.94 | 51.46 78.43 | 78.33 | 78.14 | 78.08 | 77.80 | 77.43
#        RbA 69.57 | 69.79 | 69.99 | 70.00 | 70.39 | 70.83 73.77 | 84.74 | 86.97 | 87.34 | 87.97 | 88.25 26.00 | 25.97 | 25.97 | 25.96 | 25.93 | 25.92 55.85 | 56.16 | 56.11 | 56.08 | 55.98 | 55.91 74.12 | 74.55 | 74.62 | 74.65 | 75.01 | 75.09
#
# Temperature values: [0.5, 0.75, 1.0, 1.1, 1.5, 2.0]
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# FPR95 (%) — Impact of Temperature Scaling
#
#     Method                                         RA-21                                         RO-21                                        FS L&F                                     FS Static                                      RoadAnom
#        MSP 33.73 | 33.73 | 33.73 | 33.73 | 33.73 | 33.73       0.55 | 0.55 | 0.55 | 0.55 | 0.55 | 0.55 14.91 | 14.91 | 14.90 | 14.90 | 14.90 | 14.90 34.94 | 34.94 | 34.94 | 34.94 | 34.94 | 34.93 19.37 | 19.33 | 19.31 | 19.30 | 19.29 | 19.28
# MaxEntropy 33.68 | 33.63 | 33.60 | 33.58 | 33.55 | 33.53       0.59 | 0.64 | 0.68 | 0.69 | 0.71 | 0.72 14.83 | 14.76 | 14.72 | 14.71 | 14.67 | 14.65 34.91 | 34.87 | 34.84 | 34.84 | 34.79 | 34.77 19.03 | 18.88 | 18.79 | 18.77 | 18.69 | 18.63
#        RbA 76.02 | 78.10 | 80.06 | 84.05 | 85.55 | 91.98 99.95 | 99.95 | 99.95 | 99.95 | 99.95 | 99.94    67.27 | 16.61 | 8.79 | 9.03 | 9.65 | 10.05 84.55 | 84.60 | 82.68 | 82.35 | 73.52 | 35.88 44.02 | 20.37 | 20.41 | 19.76 | 18.34 | 17.96
#
# Temperature values: [0.5, 0.75, 1.0, 1.1, 1.5, 2.0]
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BEST TEMPERATURE (highest AUPRC)
#
#   Dataset     Method  Best T  AuPRC (%)  FPR95 (%)
#     RA-21        MSP    2.00      74.55      33.73
#     RO-21        MSP    2.00      90.11       0.55
#    FS L&F        MSP    2.00      25.44      14.90
# FS Static        MSP    2.00      54.36      34.93
#  RoadAnom        MSP    2.00      75.87      19.28
#     RA-21 MaxEntropy    2.00      77.91      33.53
#     RO-21 MaxEntropy    0.50      90.09       0.59
#    FS L&F MaxEntropy    1.00      29.56      14.72
# FS Static MaxEntropy    0.50      53.21      34.91
#  RoadAnom MaxEntropy    0.50      78.43      19.03
#     RA-21        RbA    2.00      70.83      91.98
#     RO-21        RbA    2.00      88.25      99.94
#    FS L&F        RbA    0.50      26.00      67.27
# FS Static        RbA    0.75      56.16      84.60
#  RoadAnom        RbA    2.00      75.09      17.96
#
#
# ====================================================================================================
# MODEL: EoMT-Fine-tuned
# ====================================================================================================
#
# AuPRC (%) — Impact of Temperature Scaling
#
#     Method                                         RA-21                                         RO-21                                        FS L&F                                     FS Static                                      RoadAnom
#        MSP 58.59 | 57.58 | 57.15 | 57.05 | 56.78 | 56.61 73.69 | 73.63 | 73.61 | 73.60 | 73.58 | 73.57 27.07 | 27.10 | 27.11 | 27.11 | 27.12 | 27.13 53.35 | 53.39 | 53.41 | 53.41 | 53.43 | 53.43 54.96 | 54.98 | 54.99 | 54.99 | 55.00 | 55.00
# MaxEntropy 54.10 | 54.37 | 54.49 | 54.47 | 54.58 | 54.65 73.43 | 72.96 | 72.62 | 72.52 | 72.13 | 71.69 27.91 | 28.27 | 28.56 | 28.60 | 28.92 | 29.18 53.87 | 54.10 | 54.27 | 54.32 | 54.43 | 54.50 55.83 | 56.08 | 56.22 | 56.27 | 56.41 | 56.33
#        RbA 51.52 | 51.76 | 51.82 | 51.83 | 51.86 | 51.88 62.10 | 63.36 | 64.22 | 64.43 | 65.73 | 66.12 31.42 | 30.83 | 30.61 | 30.56 | 30.43 | 30.36 56.29 | 56.55 | 56.29 | 56.19 | 55.91 | 55.73 52.39 | 54.60 | 56.14 | 56.30 | 56.51 | 56.57
#
# Temperature values: [0.5, 0.75, 1.0, 1.1, 1.5, 2.0]
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# FPR95 (%) — Impact of Temperature Scaling
#
#     Method                                         RA-21                                         RO-21                                        FS L&F                                     FS Static                                      RoadAnom
#        MSP 98.60 | 98.60 | 98.61 | 98.61 | 98.61 | 98.62 25.10 | 25.10 | 25.09 | 25.09 | 25.09 | 25.09 26.22 | 26.17 | 26.16 | 26.16 | 26.16 | 26.15 39.78 | 39.75 | 39.74 | 39.74 | 39.73 | 39.72 16.27 | 16.24 | 16.22 | 16.22 | 16.21 | 16.20
# MaxEntropy 98.71 | 98.81 | 98.82 | 98.82 | 98.82 | 98.82 28.83 | 36.81 | 57.49 | 45.00 | 58.44 | 60.82 26.21 | 26.26 | 26.33 | 26.34 | 26.28 | 26.24 39.53 | 39.40 | 39.25 | 39.19 | 39.06 | 38.76 15.28 | 14.99 | 14.78 | 14.74 | 14.61 | 14.51
#        RbA 99.53 | 99.78 | 99.85 | 99.86 | 99.87 | 99.87 99.98 | 99.98 | 99.98 | 99.98 | 99.98 | 99.98 78.97 | 23.06 | 26.92 | 28.24 | 25.75 | 24.49 89.51 | 90.28 | 90.34 | 90.29 | 90.07 | 89.65 81.57 | 74.33 | 13.38 | 12.37 | 12.08 | 12.09
#
# Temperature values: [0.5, 0.75, 1.0, 1.1, 1.5, 2.0]
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# BEST TEMPERATURE (highest AUPRC)
#
#   Dataset     Method  Best T  AuPRC (%)  FPR95 (%)
#     RA-21        MSP    0.50      58.59      98.60
#     RO-21        MSP    0.50      73.69      25.10
#    FS L&F        MSP    2.00      27.13      26.15
# FS Static        MSP    2.00      53.43      39.72
#  RoadAnom        MSP    2.00      55.00      16.20
#     RA-21 MaxEntropy    2.00      54.65      98.82
#     RO-21 MaxEntropy    0.50      73.43      28.83
#    FS L&F MaxEntropy    2.00      29.18      26.24
# FS Static MaxEntropy    2.00      54.50      38.76
#  RoadAnom MaxEntropy    1.50      56.41      14.61
#     RA-21        RbA    2.00      51.88      99.87
#     RO-21        RbA    2.00      66.12      99.98
#    FS L&F        RbA    0.50      31.42      78.97
# FS Static        RbA    0.75      56.55      90.28
#  RoadAnom        RbA    2.00      56.57      12.09
#
# Saved detailed results to /content/drive/MyDrive/FAIMDL/results/final/eomt_cityscapes_temperature.csv
#
# Saved detailed results to /content/drive/MyDrive/FAIMDL/results/final/eomt_fine_tuned_temperature.csv
#
# All temperature scaling tables and CSVs saved to /content/drive/MyDrive/FAIMDL/results/final/
