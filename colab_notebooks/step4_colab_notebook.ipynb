# %%
# !nvidia-smi
# Out:
# Sat May 23 11:02:58 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   38C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone --branch feature/omer https://github.com/omerzkan/eomt-anomaly-segmentation.git cloned_repo_feature_omer
# %cd cloned_repo_feature_omer
# Out:
# Cloning into 'cloned_repo_feature_omer'...
# remote: Enumerating objects: 324, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 324 (delta 16), reused 21 (delta 7), pack-reused 292 (from 1)
# Receiving objects: 100% (324/324), 26.92 MiB | 13.89 MiB/s, done.
# Resolving deltas: 100% (138/138), done.
# /content/cloned_repo_feature_omer

# %% [markdown]
# This command will clone the `feature/omer` branch into a new directory named `cloned_repo_feature_omer` and then change the current directory to it. Make sure to replace `omerzkan` and `eomt-anomaly-segmentation` with your actual GitHub username and repository name if they are different.

# %%
# !pip install -r eval/requirements.txt
# !pip install -r eomt/requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'eval/requirements.txt'
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'eomt/requirements.txt'

# %%
"""
# %cd /content/cloned_repo_feature_omer/eomt

# !python3 main.py validate \
  -c configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --trainer.devices 1 \
  --data.batch_size 1 \
  --data.path /content/drive/MyDrive/FAIMDL/data \
  --model.ckpt_path /content/drive/MyDrive/FAIMDL/checkpoints/eomt_cityscapes.bin \
  --model.network.masked_attn_enabled False
"""
# Out:
# '\n%cd /content/cloned_repo_feature_omer/eomt\n\n!python3 main.py validate   -c configs/dinov2/cityscapes/semantic/eomt_base_640.yaml   --trainer.devices 1   --data.batch_size 1   --data.path /content/drive/MyDrive/FAIMDL/data   --model.ckpt_path /content/drive/MyDrive/FAIMDL/checkpoints/eomt_cityscapes.bin   --model.network.masked_attn_enabled False\n'

# %%
# !pip install --upgrade wandb

import wandb
from google.colab import userdata

# Retrieve the full API key from Colab secrets
wandb_api_key = userdata.get('WANDB_API_KEY')

# Log in with the full API key (wandb natively supports the 'wandb_v1_' prefix)
wandb.login(key=wandb_api_key)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 126.8 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.25.1
#     Uninstalling wandb-0.25.1:
#       Successfully uninstalled wandb-0.25.1
# ...
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipykernel_288/867252761.py in <cell line: 0>()
#       5
#       6 # Retrieve the full API key from Colab secrets
# ----> 7 wandb_api_key = userdata.get('WANDB_API_KEY')
#       8
#       9 # Log in with the full API key (wandb natively supports the 'wandb_v1_' prefix)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# ...

# %% [markdown]
# ### Logging into Weights & Biases
#
# The previous error indicated that the API key was too long. This often happens if you copy the entire string including `wandb_v1_`. The `wandb.login()` function expects only the 40-character alphanumeric part of the key.
#
# To securely store your API key in Colab, use the Secrets manager (the 🔑 icon on the left panel). Store your W&B API key there with the name `WANDB_API_KEY`.
#
# The following code will retrieve your API key from Colab secrets and log you into Weights & Biases.

# %%
# %cd /content/cloned_repo_feature_omer
# !git pull

import os

current_dir = os.getcwd()
print("current dir is: ")
if not current_dir.endswith('cloned_repo_feature_omer'):
    # %cd /content/cloned_repo_feature_omer
    print(current_dir)
else:
  print(current_dir)
# Out:
# /content/cloned_repo_feature_omer
# Already up to date.
# current dir is:
# /content/cloned_repo_feature_omer

# %%
# %cd /content/cloned_repo_feature_omer
# !python3 step4/eval_coco_step4.py
# Out:
# /content/cloned_repo_feature_omer
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: omerozkann1010 (omerozkann1010-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Val set size: 500 images
#
# ***************** COCO TRAINED EOMT EVALUATION ON CITYSCAPES DATASET *****************
#
# ...
# SANITY CHECK: READ YAML FILE - SEE THE DICT
# ...
#
# Sanity Check: This is the loaded config file
#
# trainer:{'max_epochs': 24, 'logger': {'class_path': 'lightning.pytorch.loggers.wandb.WandbLogger', 'init_args': {'resume': 'allow', 'project': 'eomt', 'name': 'coco_panoptic_eomt_base_640'}}}
#
# ...
